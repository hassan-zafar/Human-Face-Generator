# %% [markdown]
# **Importing Required libraries**

# %%
import tensorflow as tf

import os
import time

import matplotlib.pyplot as plt
# from IPython import display

# %% [markdown]
# **Unzip folders that we uploaded to Google Colab Server**

# %%
# !unzip AllHumans.zip
# Out:
# Archive:  AllHumans.zip
#    creating: AllHumans/
#   inflating: AllHumans/glued_human_face_890.jpg
#   inflating: AllHumans/glued_human_face_891.jpg
#   inflating: AllHumans/glued_human_face_892.jpg
#   inflating: AllHumans/glued_human_face_893.jpg
#   inflating: AllHumans/glued_human_face_894.jpg
#   inflating: AllHumans/glued_human_face_895.jpg
#   inflating: AllHumans/glued_human_face_896.jpg
#   inflating: AllHumans/glued_human_face_60.jpg
#   inflating: AllHumans/glued_human_face_61.jpg
#   inflating: AllHumans/glued_human_face_62.jpg
#   inflating: AllHumans/glued_human_face_63.jpg
#   inflating: AllHumans/glued_human_face_64.jpg
#   inflating: AllHumans/glued_human_face_65.jpg
#   inflating: AllHumans/glued_human_face_66.jpg
#   inflating: AllHumans/glued_human_face_67.jpg
#   inflating: AllHumans/glued_human_face_68.jpg
#   inflating: AllHumans/glued_human_face_69.jpg
#   inflating: AllHumans/glued_human_face_70.jpg
#   inflating: AllHumans/glued_human_face_71.jpg
#   inflating: AllHumans/glued_human_face_72.jpg
#   inflating: AllHumans/glued_human_face_73.jpg
#   inflating: AllHumans/glued_human_face_74.jpg
#   inflating: AllHumans/glued_human_face_75.jpg
#   inflating: AllHumans/glued_human_face_76.jpg
#   inflating: AllHumans/glued_human_face_77.jpg
#   inflating: AllHumans/glued_human_face_78.jpg
#   inflating: AllHumans/glued_human_face_79.jpg
#   inflating: AllHumans/glued_human_face_80.jpg
#   inflating: AllHumans/glued_human_face_81.jpg
#   inflating: AllHumans/glued_human_face_82.jpg
#   inflating: AllHumans/glued_human_face_83.jpg
#   inflating: AllHumans/glued_human_face_84.jpg
#   inflating: AllHumans/glued_human_face_85.jpg
#   inflating: AllHumans/glued_human_face_86.jpg
#   inflating: AllHumans/glued_human_face_87.jpg
#   inflating: AllHumans/glued_human_face_88.jpg
#   inflating: AllHumans/glued_human_face_89.jpg
#   inflating: AllHumans/glued_human_face_90.jpg
#   inflating: AllHumans/glued_human_face_91.jpg
#   inflating: AllHumans/glued_human_face_92.jpg
#   inflating: AllHumans/glued_human_face_93.jpg
#   inflating: AllHumans/glued_human_face_94.jpg
#   inflating: AllHumans/glued_human_face_95.jpg
#   inflating: AllHumans/glued_human_face_96.jpg
#   inflating: AllHumans/glued_human_face_97.jpg
#   inflating: AllHumans/glued_human_face_98.jpg
#   inflating: AllHumans/glued_human_face_99.jpg
#   inflating: AllHumans/glued_human_face_100.jpg
#   inflating: AllHumans/glued_human_face_101.jpg
#   inflating: AllHumans/glued_human_face_102.jpg
#   inflating: AllHumans/glued_human_face_103.jpg
#   inflating: AllHumans/glued_human_face_104.jpg
#   inflating: AllHumans/glued_human_face_105.jpg
#   inflating: AllHumans/glued_human_face_106.jpg
#   inflating: AllHumans/glued_human_face_107.jpg
#   inflating: AllHumans/glued_human_face_108.jpg
#   inflating: AllHumans/glued_human_face_109.jpg
#   inflating: AllHumans/glued_human_face_110.jpg
#   inflating: AllHumans/glued_human_face_111.jpg
#   inflating: AllHumans/glued_human_face_112.jpg
#   inflating: AllHumans/glued_human_face_113.jpg
#   inflating: AllHumans/glued_human_face_114.jpg
#   inflating: AllHumans/glued_human_face_115.jpg
#   inflating: AllHumans/glued_human_face_116.jpg
#   inflating: AllHumans/glued_human_face_117.jpg
#   inflating: AllHumans/glued_human_face_118.jpg
#   inflating: AllHumans/glued_human_face_119.jpg
#   inflating: AllHumans/glued_human_face_120.jpg
#   inflating: AllHumans/glued_human_face_121.jpg
#   inflating: AllHumans/glued_human_face_122.jpg
#   inflating: AllHumans/glued_human_face_123.jpg
#   inflating: AllHumans/glued_human_face_124.jpg
#   inflating: AllHumans/glued_human_face_125.jpg
#   inflating: AllHumans/glued_human_face_126.jpg
#   inflating: AllHumans/glued_human_face_127.jpg
#   inflating: AllHumans/glued_human_face_128.jpg
#   inflating: AllHumans/glued_human_face_129.jpg
#   inflating: AllHumans/glued_human_face_130.jpg
#   inflating: AllHumans/glued_human_face_131.jpg
#   inflating: AllHumans/glued_human_face_132.jpg
#   inflating: AllHumans/glued_human_face_133.jpg
#   inflating: AllHumans/glued_human_face_134.jpg
#   inflating: AllHumans/glued_human_face_135.jpg
#   inflating: AllHumans/glued_human_face_136.jpg
#   inflating: AllHumans/glued_human_face_137.jpg
#   inflating: AllHumans/glued_human_face_138.jpg
#   inflating: AllHumans/glued_human_face_139.jpg
#   inflating: AllHumans/glued_human_face_140.jpg
#   inflating: AllHumans/glued_human_face_141.jpg
#   inflating: AllHumans/glued_human_face_142.jpg
#   inflating: AllHumans/glued_human_face_143.jpg
#   inflating: AllHumans/glued_human_face_144.jpg
#   inflating: AllHumans/glued_human_face_145.jpg
#   inflating: AllHumans/glued_human_face_146.jpg
#   inflating: AllHumans/glued_human_face_147.jpg
#   inflating: AllHumans/glued_human_face_148.jpg
#   inflating: AllHumans/glued_human_face_149.jpg
#   inflating: AllHumans/glued_human_face_150.jpg
#   inflating: AllHumans/glued_human_face_151.jpg
#   inflating: AllHumans/glued_human_face_152.jpg
#   inflating: AllHumans/glued_human_face_153.jpg
#   inflating: AllHumans/glued_human_face_154.jpg
#   inflating: AllHumans/glued_human_face_155.jpg
#   inflating: AllHumans/glued_human_face_156.jpg
#   inflating: AllHumans/glued_human_face_157.jpg
#   inflating: AllHumans/glued_human_face_158.jpg
#   inflating: AllHumans/glued_human_face_159.jpg
#   inflating: AllHumans/glued_human_face_160.jpg
#   inflating: AllHumans/glued_human_face_161.jpg
#   inflating: AllHumans/glued_human_face_162.jpg
#   inflating: AllHumans/glued_human_face_163.jpg
#   inflating: AllHumans/glued_human_face_164.jpg
#   inflating: AllHumans/glued_human_face_165.jpg
#   inflating: AllHumans/glued_human_face_166.jpg
#   inflating: AllHumans/glued_human_face_167.jpg
#   inflating: AllHumans/glued_human_face_168.jpg
#   inflating: AllHumans/glued_human_face_169.jpg
#   inflating: AllHumans/glued_human_face_170.jpg
#   inflating: AllHumans/glued_human_face_171.jpg
#   inflating: AllHumans/glued_human_face_172.jpg
#   inflating: AllHumans/glued_human_face_173.jpg
#   inflating: AllHumans/glued_human_face_174.jpg
#   inflating: AllHumans/glued_human_face_175.jpg
#   inflating: AllHumans/glued_human_face_176.jpg
#   inflating: AllHumans/glued_human_face_177.jpg
#   inflating: AllHumans/glued_human_face_178.jpg
#   inflating: AllHumans/glued_human_face_179.jpg
#   inflating: AllHumans/glued_human_face_180.jpg
#   inflating: AllHumans/glued_human_face_181.jpg
#   inflating: AllHumans/glued_human_face_182.jpg
#   inflating: AllHumans/glued_human_face_183.jpg
#   inflating: AllHumans/glued_human_face_184.jpg
#   inflating: AllHumans/glued_human_face_185.jpg
#   inflating: AllHumans/glued_human_face_186.jpg
#   inflating: AllHumans/glued_human_face_187.jpg
#   inflating: AllHumans/glued_human_face_188.jpg
#   inflating: AllHumans/glued_human_face_189.jpg
#   inflating: AllHumans/glued_human_face_190.jpg
#   inflating: AllHumans/glued_human_face_191.jpg
#   inflating: AllHumans/glued_human_face_192.jpg
#   inflating: AllHumans/glued_human_face_193.jpg
#   inflating: AllHumans/glued_human_face_194.jpg
#   inflating: AllHumans/glued_human_face_195.jpg
#   inflating: AllHumans/glued_human_face_196.jpg
#   inflating: AllHumans/glued_human_face_197.jpg
#   inflating: AllHumans/glued_human_face_198.jpg
#   inflating: AllHumans/glued_human_face_199.jpg
#   inflating: AllHumans/glued_human_face_200.jpg
#   inflating: AllHumans/glued_human_face_201.jpg
#   inflating: AllHumans/glued_human_face_202.jpg
#   inflating: AllHumans/glued_human_face_203.jpg
#   inflating: AllHumans/glued_human_face_204.jpg
#   inflating: AllHumans/glued_human_face_205.jpg
#   inflating: AllHumans/glued_human_face_206.jpg
#   inflating: AllHumans/glued_human_face_207.jpg
#   inflating: AllHumans/glued_human_face_208.jpg
#   inflating: AllHumans/glued_human_face_209.jpg
#   inflating: AllHumans/glued_human_face_210.jpg
#   inflating: AllHumans/glued_human_face_211.jpg
#   inflating: AllHumans/glued_human_face_212.jpg
#   inflating: AllHumans/glued_human_face_213.jpg
#   inflating: AllHumans/glued_human_face_214.jpg
#   inflating: AllHumans/glued_human_face_215.jpg
#   inflating: AllHumans/glued_human_face_216.jpg
#   inflating: AllHumans/glued_human_face_217.jpg
#   inflating: AllHumans/glued_human_face_218.jpg
#   inflating: AllHumans/glued_human_face_219.jpg
#   inflating: AllHumans/glued_human_face_220.jpg
#   inflating: AllHumans/glued_human_face_221.jpg
#   inflating: AllHumans/glued_human_face_222.jpg
#   inflating: AllHumans/glued_human_face_223.jpg
#   inflating: AllHumans/glued_human_face_224.jpg
#   inflating: AllHumans/glued_human_face_225.jpg
#   inflating: AllHumans/glued_human_face_226.jpg
#   inflating: AllHumans/glued_human_face_227.jpg
#   inflating: AllHumans/glued_human_face_228.jpg
#   inflating: AllHumans/glued_human_face_229.jpg
#   inflating: AllHumans/glued_human_face_230.jpg
#   inflating: AllHumans/glued_human_face_231.jpg
#   inflating: AllHumans/glued_human_face_232.jpg
#   inflating: AllHumans/glued_human_face_233.jpg
#   inflating: AllHumans/glued_human_face_234.jpg
#   inflating: AllHumans/glued_human_face_235.jpg
#   inflating: AllHumans/glued_human_face_236.jpg
#   inflating: AllHumans/glued_human_face_237.jpg
#   inflating: AllHumans/glued_human_face_238.jpg
#   inflating: AllHumans/glued_human_face_239.jpg
#   inflating: AllHumans/glued_human_face_240.jpg
#   inflating: AllHumans/glued_human_face_241.jpg
#   inflating: AllHumans/glued_human_face_242.jpg
#   inflating: AllHumans/glued_human_face_243.jpg
#   inflating: AllHumans/glued_human_face_244.jpg
#   inflating: AllHumans/glued_human_face_245.jpg
#   inflating: AllHumans/glued_human_face_246.jpg
#   inflating: AllHumans/glued_human_face_247.jpg
#   inflating: AllHumans/glued_human_face_248.jpg
#   inflating: AllHumans/glued_human_face_249.jpg
#   inflating: AllHumans/glued_human_face_250.jpg
#   inflating: AllHumans/glued_human_face_251.jpg
#   inflating: AllHumans/glued_human_face_252.jpg
#   inflating: AllHumans/glued_human_face_253.jpg
#   inflating: AllHumans/glued_human_face_254.jpg
#   inflating: AllHumans/glued_human_face_255.jpg
#   inflating: AllHumans/glued_human_face_256.jpg
#   inflating: AllHumans/glued_human_face_257.jpg
#   inflating: AllHumans/glued_human_face_258.jpg
#   inflating: AllHumans/glued_human_face_259.jpg
#   inflating: AllHumans/glued_human_face_260.jpg
#   inflating: AllHumans/glued_human_face_261.jpg
#   inflating: AllHumans/glued_human_face_262.jpg
#   inflating: AllHumans/glued_human_face_263.jpg
#   inflating: AllHumans/glued_human_face_264.jpg
#   inflating: AllHumans/glued_human_face_265.jpg
#   inflating: AllHumans/glued_human_face_266.jpg
#   inflating: AllHumans/glued_human_face_267.jpg
#   inflating: AllHumans/glued_human_face_268.jpg
#   inflating: AllHumans/glued_human_face_269.jpg
#   inflating: AllHumans/glued_human_face_270.jpg
#   inflating: AllHumans/glued_human_face_271.jpg
#   inflating: AllHumans/glued_human_face_272.jpg
#   inflating: AllHumans/glued_human_face_273.jpg
#   inflating: AllHumans/glued_human_face_274.jpg
#   inflating: AllHumans/glued_human_face_275.jpg
#   inflating: AllHumans/glued_human_face_276.jpg
#   inflating: AllHumans/glued_human_face_277.jpg
#   inflating: AllHumans/glued_human_face_278.jpg
#   inflating: AllHumans/glued_human_face_279.jpg
#   inflating: AllHumans/glued_human_face_280.jpg
#   inflating: AllHumans/glued_human_face_281.jpg
#   inflating: AllHumans/glued_human_face_282.jpg
#   inflating: AllHumans/glued_human_face_283.jpg
#   inflating: AllHumans/glued_human_face_284.jpg
#   inflating: AllHumans/glued_human_face_285.jpg
#   inflating: AllHumans/glued_human_face_286.jpg
#   inflating: AllHumans/glued_human_face_287.jpg
#   inflating: AllHumans/glued_human_face_288.jpg
#   inflating: AllHumans/glued_human_face_289.jpg
#   inflating: AllHumans/glued_human_face_290.jpg
#   inflating: AllHumans/glued_human_face_291.jpg
#   inflating: AllHumans/glued_human_face_292.jpg
#   inflating: AllHumans/glued_human_face_293.jpg
#   inflating: AllHumans/glued_human_face_294.jpg
#   inflating: AllHumans/glued_human_face_295.jpg
#   inflating: AllHumans/glued_human_face_296.jpg
#   inflating: AllHumans/glued_human_face_297.jpg
#   inflating: AllHumans/glued_human_face_298.jpg
#   inflating: AllHumans/glued_human_face_299.jpg
#   inflating: AllHumans/glued_human_face_300.jpg
#   inflating: AllHumans/glued_human_face_301.jpg
#   inflating: AllHumans/glued_human_face_302.jpg
#   inflating: AllHumans/glued_human_face_303.jpg
#   inflating: AllHumans/glued_human_face_304.jpg
#   inflating: AllHumans/glued_human_face_305.jpg
#   inflating: AllHumans/glued_human_face_306.jpg
#   inflating: AllHumans/glued_human_face_307.jpg
#   inflating: AllHumans/glued_human_face_308.jpg
#   inflating: AllHumans/glued_human_face_309.jpg
#   inflating: AllHumans/glued_human_face_310.jpg
#   inflating: AllHumans/glued_human_face_311.jpg
#   inflating: AllHumans/glued_human_face_312.jpg
#   inflating: AllHumans/glued_human_face_313.jpg
#   inflating: AllHumans/glued_human_face_314.jpg
#   inflating: AllHumans/glued_human_face_315.jpg
#   inflating: AllHumans/glued_human_face_316.jpg
#   inflating: AllHumans/glued_human_face_317.jpg
#   inflating: AllHumans/glued_human_face_318.jpg
#   inflating: AllHumans/glued_human_face_319.jpg
#   inflating: AllHumans/glued_human_face_320.jpg
#   inflating: AllHumans/glued_human_face_321.jpg
#   inflating: AllHumans/glued_human_face_322.jpg
#   inflating: AllHumans/glued_human_face_323.jpg
#   inflating: AllHumans/glued_human_face_324.jpg
#   inflating: AllHumans/glued_human_face_325.jpg
#   inflating: AllHumans/glued_human_face_326.jpg
#   inflating: AllHumans/glued_human_face_327.jpg
#   inflating: AllHumans/glued_human_face_328.jpg
#   inflating: AllHumans/glued_human_face_329.jpg
#   inflating: AllHumans/glued_human_face_330.jpg
#   inflating: AllHumans/glued_human_face_331.jpg
#   inflating: AllHumans/glued_human_face_332.jpg
#   inflating: AllHumans/glued_human_face_333.jpg
#   inflating: AllHumans/glued_human_face_334.jpg
#   inflating: AllHumans/glued_human_face_335.jpg
#   inflating: AllHumans/glued_human_face_336.jpg
#   inflating: AllHumans/glued_human_face_337.jpg
#   inflating: AllHumans/glued_human_face_338.jpg
#   inflating: AllHumans/glued_human_face_339.jpg
#   inflating: AllHumans/glued_human_face_340.jpg
#   inflating: AllHumans/glued_human_face_341.jpg
#   inflating: AllHumans/glued_human_face_342.jpg
#   inflating: AllHumans/glued_human_face_343.jpg
#   inflating: AllHumans/glued_human_face_344.jpg
#   inflating: AllHumans/glued_human_face_345.jpg
#   inflating: AllHumans/glued_human_face_346.jpg
#   inflating: AllHumans/glued_human_face_347.jpg
#   inflating: AllHumans/glued_human_face_348.jpg
#   inflating: AllHumans/glued_human_face_349.jpg
#   inflating: AllHumans/glued_human_face_350.jpg
#   inflating: AllHumans/glued_human_face_351.jpg
#   inflating: AllHumans/glued_human_face_352.jpg
#   inflating: AllHumans/glued_human_face_353.jpg
#   inflating: AllHumans/glued_human_face_354.jpg
#   inflating: AllHumans/glued_human_face_355.jpg
#   inflating: AllHumans/glued_human_face_356.jpg
#   inflating: AllHumans/glued_human_face_357.jpg
#   inflating: AllHumans/glued_human_face_358.jpg
#   inflating: AllHumans/glued_human_face_359.jpg
#   inflating: AllHumans/glued_human_face_360.jpg
#   inflating: AllHumans/glued_human_face_361.jpg
#   inflating: AllHumans/glued_human_face_362.jpg
#   inflating: AllHumans/glued_human_face_363.jpg
#   inflating: AllHumans/glued_human_face_364.jpg
#   inflating: AllHumans/glued_human_face_365.jpg
#   inflating: AllHumans/glued_human_face_366.jpg
#   inflating: AllHumans/glued_human_face_367.jpg
#   inflating: AllHumans/glued_human_face_368.jpg
#   inflating: AllHumans/glued_human_face_369.jpg
#   inflating: AllHumans/glued_human_face_370.jpg
#   inflating: AllHumans/glued_human_face_371.jpg
#   inflating: AllHumans/glued_human_face_372.jpg
#   inflating: AllHumans/glued_human_face_373.jpg
#   inflating: AllHumans/glued_human_face_374.jpg
#   inflating: AllHumans/glued_human_face_375.jpg
#   inflating: AllHumans/glued_human_face_376.jpg
#   inflating: AllHumans/glued_human_face_377.jpg
#   inflating: AllHumans/glued_human_face_378.jpg
#   inflating: AllHumans/glued_human_face_379.jpg
#   inflating: AllHumans/glued_human_face_380.jpg
#   inflating: AllHumans/glued_human_face_381.jpg
#   inflating: AllHumans/glued_human_face_382.jpg
#   inflating: AllHumans/glued_human_face_383.jpg
#   inflating: AllHumans/glued_human_face_384.jpg
#   inflating: AllHumans/glued_human_face_385.jpg
#   inflating: AllHumans/glued_human_face_386.jpg
#   inflating: AllHumans/glued_human_face_387.jpg
#   inflating: AllHumans/glued_human_face_388.jpg
#   inflating: AllHumans/glued_human_face_389.jpg
#   inflating: AllHumans/glued_human_face_390.jpg
#   inflating: AllHumans/glued_human_face_391.jpg
#   inflating: AllHumans/glued_human_face_392.jpg
#   inflating: AllHumans/glued_human_face_393.jpg
#   inflating: AllHumans/glued_human_face_394.jpg
#   inflating: AllHumans/glued_human_face_395.jpg
#   inflating: AllHumans/glued_human_face_396.jpg
#   inflating: AllHumans/glued_human_face_397.jpg
#   inflating: AllHumans/glued_human_face_398.jpg
#   inflating: AllHumans/glued_human_face_399.jpg
#   inflating: AllHumans/glued_human_face_400.jpg
#   inflating: AllHumans/glued_human_face_401.jpg
#   inflating: AllHumans/glued_human_face_402.jpg
#   inflating: AllHumans/glued_human_face_403.jpg
#   inflating: AllHumans/glued_human_face_404.jpg
#   inflating: AllHumans/glued_human_face_405.jpg
#   inflating: AllHumans/glued_human_face_406.jpg
#   inflating: AllHumans/glued_human_face_407.jpg
#   inflating: AllHumans/glued_human_face_408.jpg
#   inflating: AllHumans/glued_human_face_409.jpg
#   inflating: AllHumans/glued_human_face_410.jpg
#   inflating: AllHumans/glued_human_face_411.jpg
#   inflating: AllHumans/glued_human_face_412.jpg
#   inflating: AllHumans/glued_human_face_413.jpg
#   inflating: AllHumans/glued_human_face_414.jpg
#   inflating: AllHumans/glued_human_face_415.jpg
#   inflating: AllHumans/glued_human_face_416.jpg
#   inflating: AllHumans/glued_human_face_417.jpg
#   inflating: AllHumans/glued_human_face_418.jpg
#   inflating: AllHumans/glued_human_face_419.jpg
#   inflating: AllHumans/glued_human_face_420.jpg
#   inflating: AllHumans/glued_human_face_421.jpg
#   inflating: AllHumans/glued_human_face_422.jpg
#   inflating: AllHumans/glued_human_face_423.jpg
#   inflating: AllHumans/glued_human_face_424.jpg
#   inflating: AllHumans/glued_human_face_425.jpg
#   inflating: AllHumans/glued_human_face_426.jpg
#   inflating: AllHumans/glued_human_face_427.jpg
#   inflating: AllHumans/glued_human_face_428.jpg
#   inflating: AllHumans/glued_human_face_429.jpg
#   inflating: AllHumans/glued_human_face_430.jpg
#   inflating: AllHumans/glued_human_face_431.jpg
#   inflating: AllHumans/glued_human_face_432.jpg
#   inflating: AllHumans/glued_human_face_433.jpg
#   inflating: AllHumans/glued_human_face_434.jpg
#   inflating: AllHumans/glued_human_face_435.jpg
#   inflating: AllHumans/glued_human_face_436.jpg
#   inflating: AllHumans/glued_human_face_437.jpg
#   inflating: AllHumans/glued_human_face_438.jpg
#   inflating: AllHumans/glued_human_face_439.jpg
#   inflating: AllHumans/glued_human_face_440.jpg
#   inflating: AllHumans/glued_human_face_441.jpg
#   inflating: AllHumans/glued_human_face_442.jpg
#   inflating: AllHumans/glued_human_face_443.jpg
#   inflating: AllHumans/glued_human_face_444.jpg
#   inflating: AllHumans/glued_human_face_445.jpg
#   inflating: AllHumans/glued_human_face_446.jpg
#   inflating: AllHumans/glued_human_face_447.jpg
#   inflating: AllHumans/glued_human_face_448.jpg
#   inflating: AllHumans/glued_human_face_449.jpg
#   inflating: AllHumans/glued_human_face_450.jpg
#   inflating: AllHumans/glued_human_face_451.jpg
#   inflating: AllHumans/glued_human_face_452.jpg
#   inflating: AllHumans/glued_human_face_453.jpg
#   inflating: AllHumans/glued_human_face_454.jpg
#   inflating: AllHumans/glued_human_face_455.jpg
#   inflating: AllHumans/glued_human_face_456.jpg
#   inflating: AllHumans/glued_human_face_457.jpg
#   inflating: AllHumans/glued_human_face_458.jpg
#   inflating: AllHumans/glued_human_face_459.jpg
#   inflating: AllHumans/glued_human_face_460.jpg
#   inflating: AllHumans/glued_human_face_461.jpg
#   inflating: AllHumans/glued_human_face_462.jpg
#   inflating: AllHumans/glued_human_face_463.jpg
#   inflating: AllHumans/glued_human_face_464.jpg
#   inflating: AllHumans/glued_human_face_465.jpg
#   inflating: AllHumans/glued_human_face_466.jpg
#   inflating: AllHumans/glued_human_face_467.jpg
#   inflating: AllHumans/glued_human_face_468.jpg
#   inflating: AllHumans/glued_human_face_469.jpg
#   inflating: AllHumans/glued_human_face_470.jpg
#   inflating: AllHumans/glued_human_face_471.jpg
#   inflating: AllHumans/glued_human_face_472.jpg
#   inflating: AllHumans/glued_human_face_473.jpg
#   inflating: AllHumans/glued_human_face_474.jpg
#   inflating: AllHumans/glued_human_face_475.jpg
#   inflating: AllHumans/glued_human_face_476.jpg
#   inflating: AllHumans/glued_human_face_477.jpg
#   inflating: AllHumans/glued_human_face_478.jpg
#   inflating: AllHumans/glued_human_face_479.jpg
#   inflating: AllHumans/glued_human_face_480.jpg
#   inflating: AllHumans/glued_human_face_481.jpg
#   inflating: AllHumans/glued_human_face_482.jpg
#   inflating: AllHumans/glued_human_face_483.jpg
#   inflating: AllHumans/glued_human_face_484.jpg
#   inflating: AllHumans/glued_human_face_485.jpg
#   inflating: AllHumans/glued_human_face_486.jpg
#   inflating: AllHumans/glued_human_face_487.jpg
#   inflating: AllHumans/glued_human_face_488.jpg
#   inflating: AllHumans/glued_human_face_489.jpg
#   inflating: AllHumans/glued_human_face_490.jpg
#   inflating: AllHumans/glued_human_face_491.jpg
#   inflating: AllHumans/glued_human_face_492.jpg
#   inflating: AllHumans/glued_human_face_493.jpg
#   inflating: AllHumans/glued_human_face_494.jpg
#   inflating: AllHumans/glued_human_face_495.jpg
#   inflating: AllHumans/glued_human_face_496.jpg
#   inflating: AllHumans/glued_human_face_497.jpg
#   inflating: AllHumans/glued_human_face_498.jpg
#   inflating: AllHumans/glued_human_face_499.jpg
#   inflating: AllHumans/glued_human_face_500.jpg
#   inflating: AllHumans/glued_human_face_501.jpg
#   inflating: AllHumans/glued_human_face_502.jpg
#   inflating: AllHumans/glued_human_face_503.jpg
#   inflating: AllHumans/glued_human_face_504.jpg
#   inflating: AllHumans/glued_human_face_505.jpg
#   inflating: AllHumans/glued_human_face_506.jpg
#   inflating: AllHumans/glued_human_face_507.jpg
#   inflating: AllHumans/glued_human_face_508.jpg
#   inflating: AllHumans/glued_human_face_509.jpg
#   inflating: AllHumans/glued_human_face_510.jpg
#   inflating: AllHumans/glued_human_face_511.jpg
#   inflating: AllHumans/glued_human_face_512.jpg
#   inflating: AllHumans/glued_human_face_513.jpg
#   inflating: AllHumans/glued_human_face_514.jpg
#   inflating: AllHumans/glued_human_face_515.jpg
#   inflating: AllHumans/glued_human_face_516.jpg
#   inflating: AllHumans/glued_human_face_517.jpg
#   inflating: AllHumans/glued_human_face_518.jpg
#   inflating: AllHumans/glued_human_face_519.jpg
#   inflating: AllHumans/glued_human_face_520.jpg
#   inflating: AllHumans/glued_human_face_521.jpg
#   inflating: AllHumans/glued_human_face_522.jpg
#   inflating: AllHumans/glued_human_face_523.jpg
#   inflating: AllHumans/glued_human_face_524.jpg
#   inflating: AllHumans/glued_human_face_525.jpg
#   inflating: AllHumans/glued_human_face_526.jpg
#   inflating: AllHumans/glued_human_face_527.jpg
#   inflating: AllHumans/glued_human_face_528.jpg
#   inflating: AllHumans/glued_human_face_529.jpg
#   inflating: AllHumans/glued_human_face_530.jpg
#   inflating: AllHumans/glued_human_face_531.jpg
#   inflating: AllHumans/glued_human_face_532.jpg
#   inflating: AllHumans/glued_human_face_533.jpg
#   inflating: AllHumans/glued_human_face_534.jpg
#   inflating: AllHumans/glued_human_face_535.jpg
#   inflating: AllHumans/glued_human_face_536.jpg
#   inflating: AllHumans/glued_human_face_537.jpg
#   inflating: AllHumans/glued_human_face_538.jpg
#   inflating: AllHumans/glued_human_face_539.jpg
#   inflating: AllHumans/glued_human_face_540.jpg
#   inflating: AllHumans/glued_human_face_541.jpg
#   inflating: AllHumans/glued_human_face_542.jpg
#   inflating: AllHumans/glued_human_face_543.jpg
#   inflating: AllHumans/glued_human_face_544.jpg
#   inflating: AllHumans/glued_human_face_545.jpg
#   inflating: AllHumans/glued_human_face_546.jpg
#   inflating: AllHumans/glued_human_face_547.jpg
#   inflating: AllHumans/glued_human_face_548.jpg
#   inflating: AllHumans/glued_human_face_549.jpg
#   inflating: AllHumans/glued_human_face_550.jpg
#   inflating: AllHumans/glued_human_face_551.jpg
#   inflating: AllHumans/glued_human_face_552.jpg
#   inflating: AllHumans/glued_human_face_553.jpg
#   inflating: AllHumans/glued_human_face_554.jpg
#   inflating: AllHumans/glued_human_face_555.jpg
#   inflating: AllHumans/glued_human_face_556.jpg
#   inflating: AllHumans/glued_human_face_557.jpg
#   inflating: AllHumans/glued_human_face_558.jpg
#   inflating: AllHumans/glued_human_face_559.jpg
#   inflating: AllHumans/glued_human_face_560.jpg
#   inflating: AllHumans/glued_human_face_561.jpg
#   inflating: AllHumans/glued_human_face_562.jpg
#   inflating: AllHumans/glued_human_face_563.jpg
#   inflating: AllHumans/glued_human_face_564.jpg
#   inflating: AllHumans/glued_human_face_565.jpg
#   inflating: AllHumans/glued_human_face_566.jpg
#   inflating: AllHumans/glued_human_face_567.jpg
#   inflating: AllHumans/glued_human_face_568.jpg
#   inflating: AllHumans/glued_human_face_569.jpg
#   inflating: AllHumans/glued_human_face_570.jpg
#   inflating: AllHumans/glued_human_face_571.jpg
#   inflating: AllHumans/glued_human_face_572.jpg
#   inflating: AllHumans/glued_human_face_573.jpg
#   inflating: AllHumans/glued_human_face_574.jpg
#   inflating: AllHumans/glued_human_face_575.jpg
#   inflating: AllHumans/glued_human_face_576.jpg
#   inflating: AllHumans/glued_human_face_577.jpg
#   inflating: AllHumans/glued_human_face_578.jpg
#   inflating: AllHumans/glued_human_face_579.jpg
#   inflating: AllHumans/glued_human_face_580.jpg
#   inflating: AllHumans/glued_human_face_581.jpg
#   inflating: AllHumans/glued_human_face_582.jpg
#   inflating: AllHumans/glued_human_face_583.jpg
#   inflating: AllHumans/glued_human_face_584.jpg
#   inflating: AllHumans/glued_human_face_585.jpg
#   inflating: AllHumans/glued_human_face_586.jpg
#   inflating: AllHumans/glued_human_face_587.jpg
#   inflating: AllHumans/glued_human_face_588.jpg
#   inflating: AllHumans/glued_human_face_589.jpg
#   inflating: AllHumans/glued_human_face_590.jpg
#   inflating: AllHumans/glued_human_face_591.jpg
#   inflating: AllHumans/glued_human_face_592.jpg
#   inflating: AllHumans/glued_human_face_593.jpg
#   inflating: AllHumans/glued_human_face_594.jpg
#   inflating: AllHumans/glued_human_face_595.jpg
#   inflating: AllHumans/glued_human_face_596.jpg
#   inflating: AllHumans/glued_human_face_597.jpg
#   inflating: AllHumans/glued_human_face_598.jpg
#   inflating: AllHumans/glued_human_face_599.jpg
#   inflating: AllHumans/glued_human_face_600.jpg
#   inflating: AllHumans/glued_human_face_601.jpg
#   inflating: AllHumans/glued_human_face_602.jpg
#   inflating: AllHumans/glued_human_face_603.jpg
#   inflating: AllHumans/glued_human_face_604.jpg
#   inflating: AllHumans/glued_human_face_605.jpg
#   inflating: AllHumans/glued_human_face_606.jpg
#   inflating: AllHumans/glued_human_face_607.jpg
#   inflating: AllHumans/glued_human_face_608.jpg
#   inflating: AllHumans/glued_human_face_609.jpg
#   inflating: AllHumans/glued_human_face_610.jpg
#   inflating: AllHumans/glued_human_face_611.jpg
#   inflating: AllHumans/glued_human_face_612.jpg
#   inflating: AllHumans/glued_human_face_613.jpg
#   inflating: AllHumans/glued_human_face_614.jpg
#   inflating: AllHumans/glued_human_face_615.jpg
#   inflating: AllHumans/glued_human_face_616.jpg
#   inflating: AllHumans/glued_human_face_617.jpg
#   inflating: AllHumans/glued_human_face_618.jpg
#   inflating: AllHumans/glued_human_face_619.jpg
#   inflating: AllHumans/glued_human_face_620.jpg
#   inflating: AllHumans/glued_human_face_621.jpg
#   inflating: AllHumans/glued_human_face_622.jpg
#   inflating: AllHumans/glued_human_face_623.jpg
#   inflating: AllHumans/glued_human_face_624.jpg
#   inflating: AllHumans/glued_human_face_625.jpg
#   inflating: AllHumans/glued_human_face_626.jpg
#   inflating: AllHumans/glued_human_face_627.jpg
#   inflating: AllHumans/glued_human_face_628.jpg
#   inflating: AllHumans/glued_human_face_629.jpg
#   inflating: AllHumans/glued_human_face_630.jpg
#   inflating: AllHumans/glued_human_face_631.jpg
#   inflating: AllHumans/glued_human_face_632.jpg
#   inflating: AllHumans/glued_human_face_633.jpg
#   inflating: AllHumans/glued_human_face_634.jpg
#   inflating: AllHumans/glued_human_face_635.jpg
#   inflating: AllHumans/glued_human_face_636.jpg
#   inflating: AllHumans/glued_human_face_637.jpg
#   inflating: AllHumans/glued_human_face_638.jpg
#   inflating: AllHumans/glued_human_face_639.jpg
#   inflating: AllHumans/glued_human_face_640.jpg
#   inflating: AllHumans/glued_human_face_641.jpg
#   inflating: AllHumans/glued_human_face_642.jpg
#   inflating: AllHumans/glued_human_face_643.jpg
#   inflating: AllHumans/glued_human_face_644.jpg
#   inflating: AllHumans/glued_human_face_645.jpg
#   inflating: AllHumans/glued_human_face_646.jpg
#   inflating: AllHumans/glued_human_face_647.jpg
#   inflating: AllHumans/glued_human_face_648.jpg
#   inflating: AllHumans/glued_human_face_649.jpg
#   inflating: AllHumans/glued_human_face_650.jpg
#   inflating: AllHumans/glued_human_face_651.jpg
#   inflating: AllHumans/glued_human_face_652.jpg
#   inflating: AllHumans/glued_human_face_653.jpg
#   inflating: AllHumans/glued_human_face_654.jpg
#   inflating: AllHumans/glued_human_face_655.jpg
#   inflating: AllHumans/glued_human_face_656.jpg
#   inflating: AllHumans/glued_human_face_657.jpg
#   inflating: AllHumans/glued_human_face_658.jpg
#   inflating: AllHumans/glued_human_face_659.jpg
#   inflating: AllHumans/glued_human_face_660.jpg
#   inflating: AllHumans/glued_human_face_661.jpg
#   inflating: AllHumans/glued_human_face_662.jpg
#   inflating: AllHumans/glued_human_face_663.jpg
#   inflating: AllHumans/glued_human_face_664.jpg
#   inflating: AllHumans/glued_human_face_665.jpg
#   inflating: AllHumans/glued_human_face_666.jpg
#   inflating: AllHumans/glued_human_face_667.jpg
#   inflating: AllHumans/glued_human_face_668.jpg
#   inflating: AllHumans/glued_human_face_669.jpg
#   inflating: AllHumans/glued_human_face_670.jpg
#   inflating: AllHumans/glued_human_face_671.jpg
#   inflating: AllHumans/glued_human_face_672.jpg
#   inflating: AllHumans/glued_human_face_673.jpg
#   inflating: AllHumans/glued_human_face_674.jpg
#   inflating: AllHumans/glued_human_face_675.jpg
#   inflating: AllHumans/glued_human_face_676.jpg
#   inflating: AllHumans/glued_human_face_677.jpg
#   inflating: AllHumans/glued_human_face_678.jpg
#   inflating: AllHumans/glued_human_face_679.jpg
#   inflating: AllHumans/glued_human_face_680.jpg
#   inflating: AllHumans/glued_human_face_681.jpg
#   inflating: AllHumans/glued_human_face_682.jpg
#   inflating: AllHumans/glued_human_face_683.jpg
#   inflating: AllHumans/glued_human_face_684.jpg
#   inflating: AllHumans/glued_human_face_685.jpg
#   inflating: AllHumans/glued_human_face_686.jpg
#   inflating: AllHumans/glued_human_face_687.jpg
#   inflating: AllHumans/glued_human_face_688.jpg
#   inflating: AllHumans/glued_human_face_689.jpg
#   inflating: AllHumans/glued_human_face_690.jpg
#   inflating: AllHumans/glued_human_face_691.jpg
#   inflating: AllHumans/glued_human_face_692.jpg
#   inflating: AllHumans/glued_human_face_693.jpg
#   inflating: AllHumans/glued_human_face_694.jpg
#   inflating: AllHumans/glued_human_face_695.jpg
#   inflating: AllHumans/glued_human_face_696.jpg
#   inflating: AllHumans/glued_human_face_697.jpg
#   inflating: AllHumans/glued_human_face_698.jpg
#   inflating: AllHumans/glued_human_face_699.jpg
#   inflating: AllHumans/glued_human_face_700.jpg
#   inflating: AllHumans/glued_human_face_701.jpg
#   inflating: AllHumans/glued_human_face_702.jpg
#   inflating: AllHumans/glued_human_face_703.jpg
#   inflating: AllHumans/glued_human_face_704.jpg
#   inflating: AllHumans/glued_human_face_705.jpg
#   inflating: AllHumans/glued_human_face_706.jpg
#   inflating: AllHumans/glued_human_face_707.jpg
#   inflating: AllHumans/glued_human_face_708.jpg
#   inflating: AllHumans/glued_human_face_709.jpg
#   inflating: AllHumans/glued_human_face_710.jpg
#   inflating: AllHumans/glued_human_face_711.jpg
#   inflating: AllHumans/glued_human_face_712.jpg
#   inflating: AllHumans/glued_human_face_713.jpg
#   inflating: AllHumans/glued_human_face_714.jpg
#   inflating: AllHumans/glued_human_face_715.jpg
#   inflating: AllHumans/glued_human_face_716.jpg
#   inflating: AllHumans/glued_human_face_717.jpg
#   inflating: AllHumans/glued_human_face_718.jpg
#   inflating: AllHumans/glued_human_face_719.jpg
#   inflating: AllHumans/glued_human_face_720.jpg
#   inflating: AllHumans/glued_human_face_721.jpg
#   inflating: AllHumans/glued_human_face_722.jpg
#   inflating: AllHumans/glued_human_face_723.jpg
#   inflating: AllHumans/glued_human_face_724.jpg
#   inflating: AllHumans/glued_human_face_725.jpg
#   inflating: AllHumans/glued_human_face_726.jpg
#   inflating: AllHumans/glued_human_face_727.jpg
#   inflating: AllHumans/glued_human_face_728.jpg
#   inflating: AllHumans/glued_human_face_729.jpg
#   inflating: AllHumans/glued_human_face_730.jpg
#   inflating: AllHumans/glued_human_face_731.jpg
#   inflating: AllHumans/glued_human_face_732.jpg
#   inflating: AllHumans/glued_human_face_733.jpg
#   inflating: AllHumans/glued_human_face_734.jpg
#   inflating: AllHumans/glued_human_face_735.jpg
#   inflating: AllHumans/glued_human_face_736.jpg
#   inflating: AllHumans/glued_human_face_737.jpg
#   inflating: AllHumans/glued_human_face_738.jpg
#   inflating: AllHumans/glued_human_face_739.jpg
#   inflating: AllHumans/glued_human_face_740.jpg
#   inflating: AllHumans/glued_human_face_741.jpg
#   inflating: AllHumans/glued_human_face_742.jpg
#   inflating: AllHumans/glued_human_face_743.jpg
#   inflating: AllHumans/glued_human_face_744.jpg
#   inflating: AllHumans/glued_human_face_745.jpg
#   inflating: AllHumans/glued_human_face_746.jpg
#   inflating: AllHumans/glued_human_face_747.jpg
#   inflating: AllHumans/glued_human_face_748.jpg
#   inflating: AllHumans/glued_human_face_749.jpg
#   inflating: AllHumans/glued_human_face_750.jpg
#   inflating: AllHumans/glued_human_face_751.jpg
#   inflating: AllHumans/glued_human_face_752.jpg
#   inflating: AllHumans/glued_human_face_753.jpg
#   inflating: AllHumans/glued_human_face_754.jpg
#   inflating: AllHumans/glued_human_face_755.jpg
#   inflating: AllHumans/glued_human_face_756.jpg
#   inflating: AllHumans/glued_human_face_757.jpg
#   inflating: AllHumans/glued_human_face_758.jpg
#   inflating: AllHumans/glued_human_face_759.jpg
#   inflating: AllHumans/glued_human_face_760.jpg
#   inflating: AllHumans/glued_human_face_761.jpg
#   inflating: AllHumans/glued_human_face_762.jpg
#   inflating: AllHumans/glued_human_face_763.jpg
#   inflating: AllHumans/glued_human_face_764.jpg
#   inflating: AllHumans/glued_human_face_765.jpg
#   inflating: AllHumans/glued_human_face_766.jpg
#   inflating: AllHumans/glued_human_face_767.jpg
#   inflating: AllHumans/glued_human_face_768.jpg
#   inflating: AllHumans/glued_human_face_769.jpg
#   inflating: AllHumans/glued_human_face_770.jpg
#   inflating: AllHumans/glued_human_face_771.jpg
#   inflating: AllHumans/glued_human_face_772.jpg
#   inflating: AllHumans/glued_human_face_773.jpg
#   inflating: AllHumans/glued_human_face_774.jpg
#   inflating: AllHumans/glued_human_face_775.jpg
#   inflating: AllHumans/glued_human_face_776.jpg
#   inflating: AllHumans/glued_human_face_777.jpg
#   inflating: AllHumans/glued_human_face_778.jpg
#   inflating: AllHumans/glued_human_face_779.jpg
#   inflating: AllHumans/glued_human_face_780.jpg
#   inflating: AllHumans/glued_human_face_781.jpg
#   inflating: AllHumans/glued_human_face_782.jpg
#   inflating: AllHumans/glued_human_face_783.jpg
#   inflating: AllHumans/glued_human_face_784.jpg
#   inflating: AllHumans/glued_human_face_785.jpg
#   inflating: AllHumans/glued_human_face_786.jpg
#   inflating: AllHumans/glued_human_face_787.jpg
#   inflating: AllHumans/glued_human_face_788.jpg
#   inflating: AllHumans/glued_human_face_789.jpg
#   inflating: AllHumans/glued_human_face_790.jpg
#   inflating: AllHumans/glued_human_face_791.jpg
#   inflating: AllHumans/glued_human_face_792.jpg
#   inflating: AllHumans/glued_human_face_793.jpg
#   inflating: AllHumans/glued_human_face_794.jpg
#   inflating: AllHumans/glued_human_face_795.jpg
#   inflating: AllHumans/glued_human_face_796.jpg
#   inflating: AllHumans/glued_human_face_797.jpg
#   inflating: AllHumans/glued_human_face_798.jpg
#   inflating: AllHumans/glued_human_face_799.jpg
#   inflating: AllHumans/glued_human_face_800.jpg
#   inflating: AllHumans/glued_human_face_801.jpg
#   inflating: AllHumans/glued_human_face_802.jpg
#   inflating: AllHumans/glued_human_face_803.jpg
#   inflating: AllHumans/glued_human_face_804.jpg
#   inflating: AllHumans/glued_human_face_805.jpg
#   inflating: AllHumans/glued_human_face_806.jpg
#   inflating: AllHumans/glued_human_face_807.jpg
#   inflating: AllHumans/glued_human_face_808.jpg
#   inflating: AllHumans/glued_human_face_809.jpg
#   inflating: AllHumans/glued_human_face_810.jpg
#   inflating: AllHumans/glued_human_face_811.jpg
#   inflating: AllHumans/glued_human_face_812.jpg
#   inflating: AllHumans/glued_human_face_813.jpg
#   inflating: AllHumans/glued_human_face_814.jpg
#   inflating: AllHumans/glued_human_face_815.jpg
#   inflating: AllHumans/glued_human_face_816.jpg
#   inflating: AllHumans/glued_human_face_817.jpg
#   inflating: AllHumans/glued_human_face_818.jpg
#   inflating: AllHumans/glued_human_face_819.jpg
#   inflating: AllHumans/glued_human_face_820.jpg
#   inflating: AllHumans/glued_human_face_821.jpg
#   inflating: AllHumans/glued_human_face_822.jpg
#   inflating: AllHumans/glued_human_face_823.jpg
#   inflating: AllHumans/glued_human_face_824.jpg
#   inflating: AllHumans/glued_human_face_825.jpg
#   inflating: AllHumans/glued_human_face_826.jpg
#   inflating: AllHumans/glued_human_face_827.jpg
#   inflating: AllHumans/glued_human_face_828.jpg
#   inflating: AllHumans/glued_human_face_829.jpg
#   inflating: AllHumans/glued_human_face_830.jpg
#   inflating: AllHumans/glued_human_face_831.jpg
#   inflating: AllHumans/glued_human_face_832.jpg
#   inflating: AllHumans/glued_human_face_833.jpg
#   inflating: AllHumans/glued_human_face_834.jpg
#   inflating: AllHumans/glued_human_face_835.jpg
#   inflating: AllHumans/glued_human_face_836.jpg
#   inflating: AllHumans/glued_human_face_837.jpg
#   inflating: AllHumans/glued_human_face_838.jpg
#   inflating: AllHumans/glued_human_face_839.jpg
#   inflating: AllHumans/glued_human_face_840.jpg
#   inflating: AllHumans/glued_human_face_841.jpg
#   inflating: AllHumans/glued_human_face_842.jpg
#   inflating: AllHumans/glued_human_face_843.jpg
#   inflating: AllHumans/glued_human_face_844.jpg
#   inflating: AllHumans/glued_human_face_845.jpg
#   inflating: AllHumans/glued_human_face_846.jpg
#   inflating: AllHumans/glued_human_face_847.jpg
#   inflating: AllHumans/glued_human_face_848.jpg
#   inflating: AllHumans/glued_human_face_849.jpg
#   inflating: AllHumans/glued_human_face_850.jpg
#   inflating: AllHumans/glued_human_face_851.jpg
#   inflating: AllHumans/glued_human_face_852.jpg
#   inflating: AllHumans/glued_human_face_853.jpg
#   inflating: AllHumans/glued_human_face_854.jpg
#   inflating: AllHumans/glued_human_face_855.jpg
#   inflating: AllHumans/glued_human_face_856.jpg
#   inflating: AllHumans/glued_human_face_857.jpg
#   inflating: AllHumans/glued_human_face_858.jpg
#   inflating: AllHumans/glued_human_face_859.jpg
#   inflating: AllHumans/glued_human_face_860.jpg
#   inflating: AllHumans/glued_human_face_861.jpg
#   inflating: AllHumans/glued_human_face_862.jpg
#   inflating: AllHumans/glued_human_face_863.jpg
#   inflating: AllHumans/glued_human_face_864.jpg
#   inflating: AllHumans/glued_human_face_865.jpg
#   inflating: AllHumans/glued_human_face_866.jpg
#   inflating: AllHumans/glued_human_face_867.jpg
#   inflating: AllHumans/glued_human_face_868.jpg
#   inflating: AllHumans/glued_human_face_869.jpg
#   inflating: AllHumans/glued_human_face_870.jpg
#   inflating: AllHumans/glued_human_face_871.jpg
#   inflating: AllHumans/glued_human_face_872.jpg
#   inflating: AllHumans/glued_human_face_873.jpg
#   inflating: AllHumans/glued_human_face_874.jpg
#   inflating: AllHumans/glued_human_face_875.jpg
#   inflating: AllHumans/glued_human_face_876.jpg
#   inflating: AllHumans/glued_human_face_877.jpg
#   inflating: AllHumans/glued_human_face_878.jpg
#   inflating: AllHumans/glued_human_face_879.jpg
#   inflating: AllHumans/glued_human_face_880.jpg
#   inflating: AllHumans/glued_human_face_881.jpg
#   inflating: AllHumans/glued_human_face_882.jpg
#   inflating: AllHumans/glued_human_face_883.jpg
#   inflating: AllHumans/glued_human_face_884.jpg
#   inflating: AllHumans/glued_human_face_885.jpg
#   inflating: AllHumans/glued_human_face_886.jpg
#   inflating: AllHumans/glued_human_face_887.jpg
#   inflating: AllHumans/glued_human_face_888.jpg
#   inflating: AllHumans/glued_human_face_889.jpg
#   inflating: AllHumans/human1614220695890890.jpg
#   inflating: AllHumans/human1614220695891891.jpg
#   inflating: AllHumans/human1614220695892892.jpg
#   inflating: AllHumans/human1614220695893893.jpg
#   inflating: AllHumans/human1614220695894894.jpg
#   inflating: AllHumans/human1614220695895895.jpg
#   inflating: AllHumans/human161422068900.jpg
#   inflating: AllHumans/human161422068911.jpg
#   inflating: AllHumans/human161422068922.jpg
#   inflating: AllHumans/human161422068933.jpg
#   inflating: AllHumans/human161422068944.jpg
#   inflating: AllHumans/human161422068955.jpg
#   inflating: AllHumans/human161422068966.jpg
#   inflating: AllHumans/human161422068977.jpg
#   inflating: AllHumans/human161422068988.jpg
#   inflating: AllHumans/human161422068999.jpg
#   inflating: AllHumans/human16142206891010.jpg
#   inflating: AllHumans/human16142206891111.jpg
#   inflating: AllHumans/human16142206891212.jpg
#   inflating: AllHumans/human16142206891313.jpg
#   inflating: AllHumans/human16142206891414.jpg
#   inflating: AllHumans/human16142206891515.jpg
#   inflating: AllHumans/human16142206891616.jpg
#   inflating: AllHumans/human16142206891717.jpg
#   inflating: AllHumans/human16142206891818.jpg
#   inflating: AllHumans/human16142206891919.jpg
#   inflating: AllHumans/human16142206892020.jpg
#   inflating: AllHumans/human16142206892121.jpg
#   inflating: AllHumans/human16142206892222.jpg
#   inflating: AllHumans/human16142206892323.jpg
#   inflating: AllHumans/human16142206892424.jpg
#   inflating: AllHumans/human16142206892525.jpg
#   inflating: AllHumans/human16142206892626.jpg
#   inflating: AllHumans/human16142206892727.jpg
#   inflating: AllHumans/human16142206892828.jpg
#   inflating: AllHumans/human16142206892929.jpg
#   inflating: AllHumans/human16142206893030.jpg
#   inflating: AllHumans/human16142206893131.jpg
#   inflating: AllHumans/human16142206893232.jpg
#   inflating: AllHumans/human16142206893333.jpg
#   inflating: AllHumans/human16142206893434.jpg
#   inflating: AllHumans/human16142206893535.jpg
#   inflating: AllHumans/human16142206893636.jpg
#   inflating: AllHumans/human16142206893737.jpg
#   inflating: AllHumans/human16142206893838.jpg
#   inflating: AllHumans/human16142206893939.jpg
#   inflating: AllHumans/human16142206894040.jpg
#   inflating: AllHumans/human16142206894141.jpg
#   inflating: AllHumans/human16142206894242.jpg
#   inflating: AllHumans/human16142206894343.jpg
#   inflating: AllHumans/human16142206894444.jpg
#   inflating: AllHumans/human16142206894545.jpg
#   inflating: AllHumans/human16142206894646.jpg
#   inflating: AllHumans/human16142206904747.jpg
#   inflating: AllHumans/human16142206904848.jpg
#   inflating: AllHumans/human16142206904949.jpg
#   inflating: AllHumans/human16142206905050.jpg
#   inflating: AllHumans/human16142206905151.jpg
#   inflating: AllHumans/human16142206905252.jpg
#   inflating: AllHumans/human16142206905353.jpg
#   inflating: AllHumans/human16142206905454.jpg
#   inflating: AllHumans/human16142206905555.jpg
#   inflating: AllHumans/human16142206905656.jpg
#   inflating: AllHumans/human16142206905757.jpg
#   inflating: AllHumans/human16142206905858.jpg
#   inflating: AllHumans/human16142206905959.jpg
#   inflating: AllHumans/human16142206906060.jpg
#   inflating: AllHumans/human16142206906161.jpg
#   inflating: AllHumans/human16142206906262.jpg
#   inflating: AllHumans/human16142206906363.jpg
#   inflating: AllHumans/human16142206906464.jpg
#   inflating: AllHumans/human16142206906565.jpg
#   inflating: AllHumans/human16142206906666.jpg
#   inflating: AllHumans/human16142206906767.jpg
#   inflating: AllHumans/human16142206906868.jpg
#   inflating: AllHumans/human16142206906969.jpg
#   inflating: AllHumans/human16142206907070.jpg
#   inflating: AllHumans/human16142206907171.jpg
#   inflating: AllHumans/human16142206907272.jpg
#   inflating: AllHumans/human16142206907373.jpg
#   inflating: AllHumans/human16142206907474.jpg
#   inflating: AllHumans/human16142206907575.jpg
#   inflating: AllHumans/human16142206907676.jpg
#   inflating: AllHumans/human16142206907777.jpg
#   inflating: AllHumans/human16142206907878.jpg
#   inflating: AllHumans/human16142206907979.jpg
#   inflating: AllHumans/human16142206908080.jpg
#   inflating: AllHumans/human16142206908181.jpg
#   inflating: AllHumans/human16142206908282.jpg
#   inflating: AllHumans/human16142206908383.jpg
#   inflating: AllHumans/human16142206908484.jpg
#   inflating: AllHumans/human16142206908585.jpg
#   inflating: AllHumans/human16142206908686.jpg
#   inflating: AllHumans/human16142206908787.jpg
#   inflating: AllHumans/human16142206908888.jpg
#   inflating: AllHumans/human16142206908989.jpg
#   inflating: AllHumans/human16142206909090.jpg
#   inflating: AllHumans/human16142206909191.jpg
#   inflating: AllHumans/human16142206909292.jpg
#   inflating: AllHumans/human16142206909393.jpg
#   inflating: AllHumans/human16142206909494.jpg
#   inflating: AllHumans/human16142206909595.jpg
#   inflating: AllHumans/human16142206909696.jpg
#   inflating: AllHumans/human16142206909797.jpg
#   inflating: AllHumans/human16142206909898.jpg
#   inflating: AllHumans/human16142206909999.jpg
#   inflating: AllHumans/human1614220690100100.jpg
#   inflating: AllHumans/human1614220690101101.jpg
#   inflating: AllHumans/human1614220690102102.jpg
#   inflating: AllHumans/human1614220690103103.jpg
#   inflating: AllHumans/human1614220690104104.jpg
#   inflating: AllHumans/human1614220690105105.jpg
#   inflating: AllHumans/human1614220690106106.jpg
#   inflating: AllHumans/human1614220690107107.jpg
#   inflating: AllHumans/human1614220690108108.jpg
#   inflating: AllHumans/human1614220690109109.jpg
#   inflating: AllHumans/human1614220690110110.jpg
#   inflating: AllHumans/human1614220690111111.jpg
#   inflating: AllHumans/human1614220690112112.jpg
#   inflating: AllHumans/human1614220690113113.jpg
#   inflating: AllHumans/human1614220690114114.jpg
#   inflating: AllHumans/human1614220690115115.jpg
#   inflating: AllHumans/human1614220690116116.jpg
#   inflating: AllHumans/human1614220690117117.jpg
# ...
#   inflating: AllHumans/human1614220991614614.jpg
#   inflating: AllHumans/human1614220991615615.jpg
#   inflating: AllHumans/human1614220991616616.jpg
#   inflating: AllHumans/human1614220991617617.jpg
#   inflating: AllHumans/human1614220991618618.jpg
#   inflating: AllHumans/human1614220991619619.jpg
#   inflating: AllHumans/human1614220991620620.jpg
#   inflating: AllHumans/human1614220991621621.jpg
#   inflating: AllHumans/human1614220991622622.jpg
#   inflating: AllHumans/human1614220991623623.jpg
#   inflating: AllHumans/human1614220991624624.jpg
#   inflating: AllHumans/human1614220991625625.jpg
#   inflating: AllHumans/human1614220991626626.jpg
#   inflating: AllHumans/human1614220991627627.jpg
#   inflating: AllHumans/human1614220991628628.jpg
#   inflating: AllHumans/human1614220991629629.jpg
#   inflating: AllHumans/human1614220991630630.jpg
#   inflating: AllHumans/human1614220991631631.jpg
#   inflating: AllHumans/human1614220991632632.jpg
#   inflating: AllHumans/human1614220991633633.jpg
#   inflating: AllHumans/human1614220991634634.jpg
#   inflating: AllHumans/human1614220991635635.jpg
#   inflating: AllHumans/human1614220991636636.jpg
#   inflating: AllHumans/human1614220991637637.jpg
#   inflating: AllHumans/human1614220991638638.jpg
#   inflating: AllHumans/human1614220991639639.jpg
#   inflating: AllHumans/human1614220991640640.jpg
#   inflating: AllHumans/human1614220991641641.jpg
#   inflating: AllHumans/human1614220991642642.jpg
#   inflating: AllHumans/human1614220991643643.jpg
#   inflating: AllHumans/human1614220991644644.jpg
#   inflating: AllHumans/human1614220991645645.jpg
#   inflating: AllHumans/human1614220991646646.jpg
#   inflating: AllHumans/human1614220991647647.jpg
#   inflating: AllHumans/human1614220991648648.jpg
#   inflating: AllHumans/human1614220991649649.jpg
#   inflating: AllHumans/human1614220991650650.jpg
#   inflating: AllHumans/human1614220991651651.jpg
#   inflating: AllHumans/human1614220991652652.jpg
#   inflating: AllHumans/human1614220991653653.jpg
#   inflating: AllHumans/human1614220991654654.jpg
#   inflating: AllHumans/human1614220991655655.jpg
#   inflating: AllHumans/human1614220991656656.jpg
#   inflating: AllHumans/human1614220991657657.jpg
#   inflating: AllHumans/human1614220991658658.jpg
#   inflating: AllHumans/human1614220991659659.jpg
#   inflating: AllHumans/human1614220991660660.jpg
#   inflating: AllHumans/human1614220991661661.jpg
#   inflating: AllHumans/human1614220991662662.jpg
#   inflating: AllHumans/human1614220991663663.jpg
#   inflating: AllHumans/human1614220991664664.jpg
#   inflating: AllHumans/human1614220991665665.jpg
#   inflating: AllHumans/human1614220991666666.jpg
#   inflating: AllHumans/human1614220991667667.jpg
#   inflating: AllHumans/human1614220991668668.jpg
#   inflating: AllHumans/human1614220991669669.jpg
#   inflating: AllHumans/human1614220991670670.jpg
#   inflating: AllHumans/human1614220991671671.jpg
#   inflating: AllHumans/human1614220991672672.jpg
#   inflating: AllHumans/human1614220991673673.jpg
#   inflating: AllHumans/human1614220991674674.jpg
#   inflating: AllHumans/human1614220991675675.jpg
#   inflating: AllHumans/human1614220991676676.jpg
#   inflating: AllHumans/human1614220991677677.jpg
#   inflating: AllHumans/human1614220991678678.jpg
#   inflating: AllHumans/human1614220991679679.jpg
#   inflating: AllHumans/human1614220991680680.jpg
#   inflating: AllHumans/human1614220991681681.jpg
#   inflating: AllHumans/human1614220991682682.jpg
#   inflating: AllHumans/human1614220991683683.jpg
#   inflating: AllHumans/human1614220991684684.jpg
#   inflating: AllHumans/human1614220991685685.jpg
#   inflating: AllHumans/human1614220991686686.jpg
#   inflating: AllHumans/human1614220991687687.jpg
#   inflating: AllHumans/human1614220991688688.jpg
#   inflating: AllHumans/human1614220991689689.jpg
#   inflating: AllHumans/human1614220991690690.jpg
#   inflating: AllHumans/human1614220991691691.jpg
#   inflating: AllHumans/human1614220991692692.jpg
#   inflating: AllHumans/human1614220991693693.jpg
#   inflating: AllHumans/human1614220991694694.jpg
#   inflating: AllHumans/human1614220991695695.jpg
#   inflating: AllHumans/human1614220991696696.jpg
#   inflating: AllHumans/human1614220991697697.jpg
#   inflating: AllHumans/human1614220991698698.jpg
#   inflating: AllHumans/human1614220991699699.jpg
#   inflating: AllHumans/human1614220991700700.jpg
#   inflating: AllHumans/human1614220991701701.jpg
#   inflating: AllHumans/human1614220991702702.jpg
#   inflating: AllHumans/human1614220991703703.jpg
#   inflating: AllHumans/human1614220991704704.jpg
#   inflating: AllHumans/human1614220991705705.jpg
#   inflating: AllHumans/human1614220991706706.jpg
#   inflating: AllHumans/human1614220991707707.jpg
#   inflating: AllHumans/human1614220991708708.jpg
#   inflating: AllHumans/human1614220991709709.jpg
#   inflating: AllHumans/human1614220991710710.jpg
#   inflating: AllHumans/human1614220991711711.jpg
#   inflating: AllHumans/human1614220991712712.jpg
#   inflating: AllHumans/human1614220991713713.jpg
#   inflating: AllHumans/human1614220991714714.jpg
#   inflating: AllHumans/human1614220991715715.jpg
#   inflating: AllHumans/human1614220992716716.jpg
#   inflating: AllHumans/human1614220992717717.jpg
#   inflating: AllHumans/human1614220992718718.jpg
#   inflating: AllHumans/human1614220992719719.jpg
#   inflating: AllHumans/human1614220992720720.jpg
#   inflating: AllHumans/human1614220992721721.jpg
#   inflating: AllHumans/human1614220992722722.jpg
#   inflating: AllHumans/human1614220992723723.jpg
#   inflating: AllHumans/human1614220992724724.jpg
#   inflating: AllHumans/human1614220992725725.jpg
#   inflating: AllHumans/human1614220992726726.jpg
#   inflating: AllHumans/human1614220992727727.jpg
#   inflating: AllHumans/human1614220992728728.jpg
#   inflating: AllHumans/human1614220992729729.jpg
#   inflating: AllHumans/human1614220992730730.jpg
#   inflating: AllHumans/human1614220992731731.jpg
#   inflating: AllHumans/human1614220992732732.jpg
#   inflating: AllHumans/human1614220992733733.jpg
#   inflating: AllHumans/human1614220992734734.jpg
#   inflating: AllHumans/human1614220992735735.jpg
#   inflating: AllHumans/human1614220992736736.jpg
#   inflating: AllHumans/human1614220992737737.jpg
#   inflating: AllHumans/human1614220992738738.jpg
#   inflating: AllHumans/human1614220992739739.jpg
#   inflating: AllHumans/human1614220992740740.jpg
#   inflating: AllHumans/human1614220992741741.jpg
#   inflating: AllHumans/human1614220992742742.jpg
#   inflating: AllHumans/human1614220992743743.jpg
#   inflating: AllHumans/human1614220992744744.jpg
#   inflating: AllHumans/human1614220992745745.jpg
#   inflating: AllHumans/human1614220992746746.jpg
#   inflating: AllHumans/human1614220992747747.jpg
#   inflating: AllHumans/human1614220992748748.jpg
#   inflating: AllHumans/human1614220992749749.jpg
#   inflating: AllHumans/human1614220992750750.jpg
#   inflating: AllHumans/human1614220992751751.jpg
#   inflating: AllHumans/human1614220992752752.jpg
#   inflating: AllHumans/human1614220992753753.jpg
#   inflating: AllHumans/human1614220992754754.jpg
#   inflating: AllHumans/human1614220992755755.jpg
#   inflating: AllHumans/human1614220992756756.jpg
#   inflating: AllHumans/human1614220992757757.jpg
#   inflating: AllHumans/human1614220992758758.jpg
#   inflating: AllHumans/human1614220992759759.jpg
#   inflating: AllHumans/human1614220992760760.jpg
#   inflating: AllHumans/human1614220992761761.jpg
#   inflating: AllHumans/human1614220992762762.jpg
#   inflating: AllHumans/human1614220992763763.jpg
#   inflating: AllHumans/human1614220992764764.jpg
#   inflating: AllHumans/human1614220992765765.jpg
#   inflating: AllHumans/human1614220992766766.jpg
#   inflating: AllHumans/human1614220992767767.jpg
#   inflating: AllHumans/human1614220992768768.jpg
#   inflating: AllHumans/human1614220992769769.jpg
#   inflating: AllHumans/human1614220992770770.jpg
#   inflating: AllHumans/human1614220992771771.jpg
#   inflating: AllHumans/human1614220992772772.jpg
#   inflating: AllHumans/human1614220992773773.jpg
#   inflating: AllHumans/human1614220992774774.jpg
#   inflating: AllHumans/human1614220992775775.jpg
#   inflating: AllHumans/human1614220992776776.jpg
#   inflating: AllHumans/human1614220992777777.jpg
#   inflating: AllHumans/human1614220992778778.jpg
#   inflating: AllHumans/human1614220992779779.jpg
#   inflating: AllHumans/human1614220992780780.jpg
#   inflating: AllHumans/human1614220992781781.jpg
#   inflating: AllHumans/human1614220992782782.jpg
#   inflating: AllHumans/human1614220992783783.jpg
#   inflating: AllHumans/human1614220992784784.jpg
#   inflating: AllHumans/human1614220992785785.jpg
#   inflating: AllHumans/human1614220992786786.jpg
#   inflating: AllHumans/human1614220992787787.jpg
#   inflating: AllHumans/human1614220992788788.jpg
#   inflating: AllHumans/human1614220992789789.jpg
#   inflating: AllHumans/human1614220992790790.jpg
#   inflating: AllHumans/human1614220992791791.jpg
#   inflating: AllHumans/human1614220992792792.jpg
#   inflating: AllHumans/human1614220992793793.jpg
#   inflating: AllHumans/human1614220992794794.jpg
#   inflating: AllHumans/human1614220992795795.jpg
#   inflating: AllHumans/human1614220992796796.jpg
#   inflating: AllHumans/human1614220992797797.jpg
#   inflating: AllHumans/human1614220992798798.jpg
#   inflating: AllHumans/human1614220992799799.jpg
#   inflating: AllHumans/human1614220992800800.jpg
#   inflating: AllHumans/human1614220993801801.jpg
#   inflating: AllHumans/human1614220993802802.jpg
#   inflating: AllHumans/human1614220993803803.jpg
#   inflating: AllHumans/human1614220993804804.jpg
#   inflating: AllHumans/human1614220993805805.jpg
#   inflating: AllHumans/human1614220993806806.jpg
#   inflating: AllHumans/human1614220993807807.jpg
#   inflating: AllHumans/human1614220993808808.jpg
#   inflating: AllHumans/human1614220993809809.jpg
#   inflating: AllHumans/human1614220993810810.jpg
#   inflating: AllHumans/human1614220993811811.jpg
#   inflating: AllHumans/human1614220993812812.jpg
#   inflating: AllHumans/human1614220993813813.jpg
#   inflating: AllHumans/human1614220993814814.jpg
#   inflating: AllHumans/human1614220993815815.jpg
#   inflating: AllHumans/human1614220993816816.jpg
#   inflating: AllHumans/human1614220993817817.jpg
#   inflating: AllHumans/human1614220993818818.jpg
#   inflating: AllHumans/human1614220993819819.jpg
#   inflating: AllHumans/human1614220993820820.jpg
#   inflating: AllHumans/human1614220993821821.jpg
#   inflating: AllHumans/human1614220993822822.jpg
#   inflating: AllHumans/human1614220993823823.jpg
#   inflating: AllHumans/human1614220993824824.jpg
#   inflating: AllHumans/human1614220993825825.jpg
#   inflating: AllHumans/human1614220993826826.jpg
#   inflating: AllHumans/human1614220993827827.jpg
#   inflating: AllHumans/human1614220993828828.jpg
#   inflating: AllHumans/human1614220993829829.jpg
#   inflating: AllHumans/human1614220993830830.jpg
#   inflating: AllHumans/human1614220993831831.jpg
#   inflating: AllHumans/human1614220993832832.jpg
#   inflating: AllHumans/human1614220993833833.jpg
#   inflating: AllHumans/human1614220993834834.jpg
#   inflating: AllHumans/human1614220993835835.jpg
#   inflating: AllHumans/human1614220993836836.jpg
#   inflating: AllHumans/human1614220993837837.jpg
#   inflating: AllHumans/human1614220993838838.jpg
#   inflating: AllHumans/human1614220993839839.jpg
#   inflating: AllHumans/human1614220993840840.jpg
#   inflating: AllHumans/human1614220993841841.jpg
#   inflating: AllHumans/human1614220993842842.jpg
#   inflating: AllHumans/human1614220993843843.jpg
#   inflating: AllHumans/human1614220993844844.jpg
#   inflating: AllHumans/human1614220993845845.jpg
#   inflating: AllHumans/human1614220993846846.jpg
#   inflating: AllHumans/human1614220993847847.jpg
#   inflating: AllHumans/human1614220993848848.jpg
#   inflating: AllHumans/human1614220993849849.jpg
#   inflating: AllHumans/human1614220993850850.jpg
#   inflating: AllHumans/human1614220993851851.jpg
#   inflating: AllHumans/human1614220993852852.jpg
#   inflating: AllHumans/human1614220993853853.jpg
#   inflating: AllHumans/human1614220993854854.jpg
#   inflating: AllHumans/human1614220993855855.jpg
#   inflating: AllHumans/human1614220993856856.jpg
#   inflating: AllHumans/human1614220993857857.jpg
#   inflating: AllHumans/human1614220993858858.jpg
#   inflating: AllHumans/human1614220993859859.jpg
#   inflating: AllHumans/human1614220993860860.jpg
#   inflating: AllHumans/human1614220993861861.jpg
#   inflating: AllHumans/human1614220993862862.jpg
#   inflating: AllHumans/human1614220993863863.jpg
#   inflating: AllHumans/human1614220993864864.jpg
#   inflating: AllHumans/human1614220993865865.jpg
#   inflating: AllHumans/human1614220993866866.jpg
#   inflating: AllHumans/human1614220993867867.jpg
#   inflating: AllHumans/human1614220993868868.jpg
#   inflating: AllHumans/human1614220993869869.jpg
#   inflating: AllHumans/human1614220993870870.jpg
#   inflating: AllHumans/human1614220993871871.jpg
#   inflating: AllHumans/human1614220993872872.jpg
#   inflating: AllHumans/human1614220993873873.jpg
#   inflating: AllHumans/human1614220993874874.jpg
#   inflating: AllHumans/human1614220993875875.jpg
#   inflating: AllHumans/human1614220993876876.jpg
#   inflating: AllHumans/human1614220993877877.jpg
#   inflating: AllHumans/human1614220993878878.jpg
#   inflating: AllHumans/human1614220993879879.jpg
#   inflating: AllHumans/human1614220993880880.jpg
#   inflating: AllHumans/human1614220993881881.jpg
#   inflating: AllHumans/human1614220993882882.jpg
#   inflating: AllHumans/human1614220993883883.jpg
#   inflating: AllHumans/human1614220993884884.jpg
#   inflating: AllHumans/human1614220993885885.jpg
#   inflating: AllHumans/human1614220993886886.jpg
#   inflating: AllHumans/human1614220993887887.jpg
#   inflating: AllHumans/human1614220993888888.jpg
#   inflating: AllHumans/human1614220993889889.jpg
#   inflating: AllHumans/human1614220993890890.jpg
#   inflating: AllHumans/human1614220993891891.jpg
#   inflating: AllHumans/human1614220993892892.jpg
#   inflating: AllHumans/human1614220993893893.jpg
#   inflating: AllHumans/human1614220993894894.jpg
#   inflating: AllHumans/human1614220993895895.jpg
#   inflating: AllHumans/human1614220993896896.jpg
#   inflating: AllHumans/human1614220994897897.jpg
#   inflating: AllHumans/human1614220994898898.jpg
#   inflating: AllHumans/human1614220994899899.jpg
#   inflating: AllHumans/human1614220994900900.jpg
#   inflating: AllHumans/human1614220994901901.jpg
#   inflating: AllHumans/human1614220994902902.jpg
#   inflating: AllHumans/human1614220994903903.jpg
#   inflating: AllHumans/human1614220994904904.jpg
#   inflating: AllHumans/human1614220994905905.jpg
#   inflating: AllHumans/human1614220994906906.jpg
#   inflating: AllHumans/human1614220994907907.jpg
#   inflating: AllHumans/human1614220994908908.jpg
#   inflating: AllHumans/human1614220994909909.jpg
#   inflating: AllHumans/human1614220994910910.jpg
#   inflating: AllHumans/human1614220994911911.jpg
#   inflating: AllHumans/human1614220994912912.jpg
#   inflating: AllHumans/human1614220994913913.jpg
#   inflating: AllHumans/human1614220994914914.jpg
#   inflating: AllHumans/human1614220994915915.jpg
#   inflating: AllHumans/human1614220994916916.jpg
#   inflating: AllHumans/human1614220994917917.jpg
#   inflating: AllHumans/human1614220994918918.jpg
#   inflating: AllHumans/human1614220994919919.jpg
#   inflating: AllHumans/human1614220994920920.jpg
#   inflating: AllHumans/human1614220994921921.jpg
#   inflating: AllHumans/human1614220994922922.jpg
#   inflating: AllHumans/human1614220994923923.jpg
#   inflating: AllHumans/human1614220994924924.jpg
#   inflating: AllHumans/human1614220994925925.jpg
#   inflating: AllHumans/human1614220994926926.jpg

# %%
# !unzip test.zip
# Out:
# Archive:  test.zip
#    creating: test/
#   inflating: test/glued_human_face_8.jpg
#   inflating: test/glued_human_face_9.jpg
#   inflating: test/glued_human_face_10.jpg
#   inflating: test/glued_human_face_11.jpg
#   inflating: test/glued_human_face_12.jpg
#   inflating: test/glued_human_face_13.jpg
#   inflating: test/glued_human_face_14.jpg
#   inflating: test/glued_human_face_15.jpg
#   inflating: test/glued_human_face_16.jpg
#   inflating: test/glued_human_face_17.jpg
#   inflating: test/glued_human_face_18.jpg
#   inflating: test/glued_human_face_19.jpg
#   inflating: test/glued_human_face_20.jpg
#   inflating: test/glued_human_face_21.jpg
#   inflating: test/glued_human_face_22.jpg
#   inflating: test/glued_human_face_23.jpg
#   inflating: test/glued_human_face_24.jpg
#   inflating: test/glued_human_face_25.jpg
#   inflating: test/glued_human_face_26.jpg
#   inflating: test/glued_human_face_27.jpg
#   inflating: test/glued_human_face_28.jpg
#   inflating: test/glued_human_face_29.jpg
#   inflating: test/glued_human_face_30.jpg
#   inflating: test/glued_human_face_31.jpg
#   inflating: test/glued_human_face_32.jpg
#   inflating: test/glued_human_face_33.jpg
#   inflating: test/glued_human_face_34.jpg
#   inflating: test/glued_human_face_35.jpg
#   inflating: test/glued_human_face_36.jpg
#   inflating: test/glued_human_face_37.jpg
#   inflating: test/glued_human_face_38.jpg
#   inflating: test/glued_human_face_39.jpg
#   inflating: test/glued_human_face_40.jpg
#   inflating: test/glued_human_face_41.jpg
#   inflating: test/glued_human_face_42.jpg
#   inflating: test/glued_human_face_43.jpg
#   inflating: test/glued_human_face_44.jpg
#   inflating: test/glued_human_face_45.jpg
#   inflating: test/glued_human_face_46.jpg
#   inflating: test/glued_human_face_47.jpg
#   inflating: test/glued_human_face_48.jpg
#   inflating: test/glued_human_face_49.jpg
#   inflating: test/glued_human_face_50.jpg
#   inflating: test/glued_human_face_51.jpg
#   inflating: test/glued_human_face_52.jpg
#   inflating: test/glued_human_face_53.jpg
#   inflating: test/glued_human_face_54.jpg
#   inflating: test/glued_human_face_55.jpg
#   inflating: test/glued_human_face_56.jpg
#   inflating: test/glued_human_face_57.jpg
#   inflating: test/glued_human_face_58.jpg
#   inflating: test/glued_human_face_59.jpg
#   inflating: test/glued_human_face_0.jpg
#   inflating: test/glued_human_face_1.jpg
#   inflating: test/glued_human_face_2.jpg
#   inflating: test/glued_human_face_3.jpg
#   inflating: test/glued_human_face_4.jpg
#   inflating: test/glued_human_face_5.jpg
#   inflating: test/glued_human_face_6.jpg
#   inflating: test/glued_human_face_7.jpg

# %% [markdown]
# **Hyperparameters for our Model**

# %%
BUFFER_SIZE = 400
BATCH_SIZE = 8
IMG_WIDTH = 256
IMG_HEIGHT = 256

# %% [markdown]
# **Path of Data**

# %%
gluedPath = 'AllHumans/'

# %% [markdown]
# **Load Data by splitting pixels and seperating images**

# %%
def load(image_file):
  image = tf.io.read_file(image_file)
  image = tf.image.decode_jpeg(image)

  w = tf.shape(image)[1]

  w = w // 2
  real_image = image[:, :w, :]
  input_image = image[:, w:, :]

  input_image = tf.cast(input_image, tf.float32)
  real_image = tf.cast(real_image, tf.float32)

  return input_image, real_image

# %% [markdown]
# **Preprocessing Data**

# %%
inp, re = load(gluedPath+'glued_human_face_60.jpg')
# casting to int for matplotlib to show the image
plt.figure()
plt.imshow(inp/255.0)
plt.figure()
plt.imshow(re/255.0)

# %%
def resize(input_image, real_image, height, width):
  input_image = tf.image.resize(input_image, [height, width],
                                method=tf.image.ResizeMethod.NEAREST_NEIGHBOR)
  real_image = tf.image.resize(real_image, [height, width],
                               method=tf.image.ResizeMethod.NEAREST_NEIGHBOR)

  return input_image, real_image

# %%
def random_crop(input_image, real_image):
  stacked_image = tf.stack([input_image, real_image], axis=0)
  cropped_image = tf.image.random_crop(
      stacked_image, size=[2, IMG_HEIGHT, IMG_WIDTH, 3])

  return cropped_image[0], cropped_image[1]

# %%
# normalizing the images to [-1, 1]

def normalize(input_image, real_image):
  input_image = (input_image / 127.5) - 1
  real_image = (real_image / 127.5) - 1

  return input_image, real_image

# %%
@tf.function()
def random_jitter(input_image, real_image):
  # resizing to 286 x 286 x 3
  input_image, real_image = resize(input_image, real_image, 286, 286)

  # randomly cropping to 256 x 256 x 3
  input_image, real_image = random_crop(input_image, real_image)

  if tf.random.uniform(()) > 0.5:
    # random mirroring
    input_image = tf.image.flip_left_right(input_image)
    real_image = tf.image.flip_left_right(real_image)

  return input_image, real_image

# %%
plt.figure(figsize=(6, 6))
for i in range(4):
  rj_inp, rj_re = random_jitter(inp, re)
  plt.subplot(2, 2, i+1),
  plt.imshow(rj_inp/255.0)
  plt.axis('off')
plt.show()

# %%
def load_image_train(image_file):
  input_image, real_image = load(image_file)
  input_image, real_image = random_jitter(input_image, real_image)
  input_image, real_image = normalize(input_image, real_image)

  return input_image, real_image

# %%
def load_image_test(image_file):
  input_image, real_image = load(image_file)
  input_image, real_image = resize(input_image, real_image,
                                   IMG_HEIGHT, IMG_WIDTH)
  input_image, real_image = normalize(input_image, real_image)

  return input_image, real_image

# %%
train_dataset = tf.data.Dataset.list_files(gluedPath+'*.jpg')
train_dataset = train_dataset.map(load_image_train)
train_dataset = train_dataset.shuffle(BUFFER_SIZE)
train_dataset = train_dataset.batch(BATCH_SIZE)

# %%
test_dataset = tf.data.Dataset.list_files('test/*.jpg')
test_dataset = test_dataset.map(load_image_test)
test_dataset = test_dataset.batch(BATCH_SIZE)

# %%
OUTPUT_CHANNELS = 3

# %% [markdown]
# **Model Architecture**

# %%
def downsample(filters, size, apply_batchnorm=True):
  initializer = tf.random_normal_initializer(0., 0.02)

  result = tf.keras.Sequential()
  result.add(
      tf.keras.layers.Conv2D(filters, size, strides=2, padding='same',
                             kernel_initializer=initializer, use_bias=False))

  if apply_batchnorm:
    result.add(tf.keras.layers.BatchNormalization())

  result.add(tf.keras.layers.LeakyReLU())

  return result

# %%
down_model = downsample(3, 4)
down_result = down_model(tf.expand_dims(inp, 0))
print (down_result.shape)
# Out:
# (1, 128, 128, 3)

# %%
def upsample(filters, size, apply_dropout=False):
  initializer = tf.random_normal_initializer(0., 0.02)

  result = tf.keras.Sequential()
  result.add(
    tf.keras.layers.Conv2DTranspose(filters, size, strides=2,
                                    padding='same',
                                    kernel_initializer=initializer,
                                    use_bias=False))

  result.add(tf.keras.layers.BatchNormalization())

  if apply_dropout:
      result.add(tf.keras.layers.Dropout(0.5))

  result.add(tf.keras.layers.ReLU())

  return result

# %%
up_model = upsample(3, 4)
up_result = up_model(down_result)
print (up_result.shape)
# Out:
# (1, 256, 256, 3)

# %% [markdown]
# **Generator**

# %%
def Generator():
  inputs = tf.keras.layers.Input(shape=[256,256,3])

  down_stack = [
    downsample(64, 4, apply_batchnorm=False), # (bs, 128, 128, 64)
    downsample(128, 4), # (bs, 64, 64, 128)
    downsample(256, 4), # (bs, 32, 32, 256)
    downsample(512, 4), # (bs, 16, 16, 512)
    downsample(512, 4), # (bs, 8, 8, 512)
    downsample(512, 4), # (bs, 4, 4, 512)
    downsample(512, 4), # (bs, 2, 2, 512)
    downsample(512, 4), # (bs, 1, 1, 512)
  ]

  up_stack = [
    upsample(512, 4, apply_dropout=True), # (bs, 2, 2, 1024)
    upsample(512, 4, apply_dropout=True), # (bs, 4, 4, 1024)
    upsample(512, 4, apply_dropout=True), # (bs, 8, 8, 1024)
    upsample(512, 4), # (bs, 16, 16, 1024)
    upsample(256, 4), # (bs, 32, 32, 512)
    upsample(128, 4), # (bs, 64, 64, 256)
    upsample(64, 4), # (bs, 128, 128, 128)
  ]

  initializer = tf.random_normal_initializer(0., 0.02)
  last = tf.keras.layers.Conv2DTranspose(OUTPUT_CHANNELS, 4,
                                         strides=2,
                                         padding='same',
                                         kernel_initializer=initializer,
                                         activation='tanh') # (bs, 256, 256, 3)

  x = inputs

  # Downsampling through the model
  skips = []
  for down in down_stack:
    x = down(x)
    skips.append(x)

  skips = reversed(skips[:-1])

  # Upsampling and establishing the skip connections
  for up, skip in zip(up_stack, skips):
    x = up(x)
    x = tf.keras.layers.Concatenate()([x, skip])

  x = last(x)

  return tf.keras.Model(inputs=inputs, outputs=x)

# %%
#If you want to start a new Generator model use this code

generator = Generator()

#If you want to load your previous generator model you can with the following code. 
#By loading it you will be able to continue training it!

# generator = tf.keras.models.load_model("trained_networkOVERNIGHT3.h5")

# %%
gen_output = generator(inp[tf.newaxis,...], training=False)
plt.imshow(gen_output[0,...])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
LAMBDA = 100

# %%
def generator_loss(disc_generated_output, gen_output, target):
  gan_loss = loss_object(tf.ones_like(disc_generated_output), disc_generated_output)

  # mean absolute error
  l1_loss = tf.reduce_mean(tf.abs(target - gen_output))

  total_gen_loss = gan_loss + (LAMBDA * l1_loss)

  return total_gen_loss, gan_loss, l1_loss

# %% [markdown]
# **Discriminator**

# %%
def Discriminator():
  initializer = tf.random_normal_initializer(0., 0.02)

  inp = tf.keras.layers.Input(shape=[256, 256, 3], name='input_image')
  tar = tf.keras.layers.Input(shape=[256, 256, 3], name='target_image')

  x = tf.keras.layers.concatenate([inp, tar]) # (bs, 256, 256, channels*2)

  down1 = downsample(64, 4, False)(x) # (bs, 128, 128, 64)
  down2 = downsample(128, 4)(down1) # (bs, 64, 64, 128)
  down3 = downsample(256, 4)(down2) # (bs, 32, 32, 256)

  zero_pad1 = tf.keras.layers.ZeroPadding2D()(down3) # (bs, 34, 34, 256)
  conv = tf.keras.layers.Conv2D(512, 4, strides=1,
                                kernel_initializer=initializer,
                                use_bias=False)(zero_pad1) # (bs, 31, 31, 512)

  batchnorm1 = tf.keras.layers.BatchNormalization()(conv)

  leaky_relu = tf.keras.layers.LeakyReLU()(batchnorm1)

  zero_pad2 = tf.keras.layers.ZeroPadding2D()(leaky_relu) # (bs, 33, 33, 512)

  last = tf.keras.layers.Conv2D(1, 4, strides=1,
                                kernel_initializer=initializer)(zero_pad2) # (bs, 30, 30, 1)

  return tf.keras.Model(inputs=[inp, tar], outputs=last)

# %%
discriminator = Discriminator()
# tf.keras.utils.plot_model(discriminator, show_shapes=True, dpi=64)

# %%
disc_out = discriminator([inp[tf.newaxis,...], gen_output], training=False)
plt.imshow(disc_out[0,...,-1], vmin=-20, vmax=20, cmap='RdBu_r')
plt.colorbar()

# %%
loss_object = tf.keras.losses.BinaryCrossentropy(from_logits=True)

# %%
def discriminator_loss(disc_real_output, disc_generated_output):
  real_loss = loss_object(tf.ones_like(disc_real_output), disc_real_output)

  generated_loss = loss_object(tf.zeros_like(disc_generated_output), disc_generated_output)

  total_disc_loss = real_loss + generated_loss

  return total_disc_loss

# %% [markdown]
# **Hyperparameters for our models, feel free to tweak these for varying results**

# %%
generator_optimizer = tf.keras.optimizers.Adam(2e-4, beta_1=0.5)
discriminator_optimizer = tf.keras.optimizers.Adam(2e-4, beta_1=0.5)

# %%
checkpoint_dir = './training_checkpoints'
checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")
checkpoint = tf.train.Checkpoint(generator_optimizer=generator_optimizer,
                                 discriminator_optimizer=discriminator_optimizer,
                                 generator=generator,
                                 discriminator=discriminator)

# %% [markdown]
# **Generate Images Function**

# %%
def generate_images(model, test_input, tar):
  prediction = model(test_input, training=True)
  plt.figure(figsize=(15,15))

  display_list = [test_input[0], tar[0], prediction[0]]
  title = ['Input Image', 'Ground Truth', 'Predicted Image']

  for i in range(3):
    plt.subplot(1, 3, i+1)
    plt.title(title[i])
    # getting the pixel values between [0, 1] to plot it.
    plt.imshow(display_list[i] * 0.5 + 0.5)
    plt.axis('off')
  plt.show()

# %%
for example_input, example_target in test_dataset.take(1):
  generate_images(generator, example_input, example_target)

# %% [markdown]
# **Training Phase**

# %%
#Change this to whatever you want, normally more epochs = better model ( but be careful of overfitting *)
EPOCHS = 1

# %%
import datetime
log_dir="logs/"

summary_writer = tf.summary.create_file_writer(
  log_dir + "fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))

# %%
@tf.function
def train_step(input_image, target, epoch):
  with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
    gen_output = generator(input_image, training=True)

    disc_real_output = discriminator([input_image, target], training=True)
    disc_generated_output = discriminator([input_image, gen_output], training=True)

    gen_total_loss, gen_gan_loss, gen_l1_loss = generator_loss(disc_generated_output, gen_output, target)
    disc_loss = discriminator_loss(disc_real_output, disc_generated_output)

  generator_gradients = gen_tape.gradient(gen_total_loss,
                                          generator.trainable_variables)
  discriminator_gradients = disc_tape.gradient(disc_loss,
                                               discriminator.trainable_variables)

  generator_optimizer.apply_gradients(zip(generator_gradients,
                                          generator.trainable_variables))
  discriminator_optimizer.apply_gradients(zip(discriminator_gradients,
                                              discriminator.trainable_variables))

  with summary_writer.as_default():
    tf.summary.scalar('gen_total_loss', gen_total_loss, step=epoch)
    tf.summary.scalar('gen_gan_loss', gen_gan_loss, step=epoch)
    tf.summary.scalar('gen_l1_loss', gen_l1_loss, step=epoch)
    tf.summary.scalar('disc_loss', disc_loss, step=epoch)

# %%
def fit(train_ds, epochs, test_ds):
  for epoch in range(epochs):
    start = time.time()

#     display.clear_output(wait=True)

    for example_input, example_target in test_ds.take(1):
      generate_images(generator, example_input, example_target)
    print("Epoch: ", epoch)

    # Train
    for n, (input_image, target) in train_ds.enumerate():
      print('.', end='')
      if (n+1) % 100 == 0:
        print()
      train_step(input_image, target, epoch)
    print()

    saving (checkpoint) the model every 20 epochs
    if (epoch + 1) % 20 == 0:
      checkpoint.save(file_prefix = checkpoint_prefix)

    print ('Time taken for epoch {} is {} sec\n'.format(epoch + 1,
                                                        time.time()-start))
  checkpoint.save(file_prefix = checkpoint_prefix)

# %% [markdown]
# **Training the Model**

# %%
fit(train_dataset, EPOCHS, test_dataset)
# Out:
# Epoch:  0
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ...............................................................
# Time taken for epoch 1 is 165.67846274375916 sec

# %% [markdown]
# **Saving the Model**

# %%
generator.save("test.h5")

# %% [markdown]
# **Testing on your own images**

# %%
from keras.models import load_model
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import load_img
from numpy import load
from numpy import expand_dims
from matplotlib import pyplot
import tensorflow as tf

def load_image(filename, size=(256,256)):
	# load image with the preferred size
	pixels = load_img(filename, target_size=size)
	# convert to numpy array
	pixels = img_to_array(pixels)
	# scale from [0,255] to [-1,1]
	pixels = (pixels - 127.5) / 127.5
	# reshape to 1 sample
	pixels = expand_dims(pixels, 0)
	return pixels


src_image = load_image('test.png')
print('Loaded', src_image.shape)
# load model
model = load_model('test.h5')

# generate image from source
gen_image = model.predict(src_image)

gen_image = tf.reshape(gen_image, [256, 256, 3])
# scale from [-1,1] to [0,1]
gen_image = (gen_image + 1) / 2.0
print('Loaded', gen_image.shape)
# plot the image
pyplot.imshow(gen_image)
pyplot.axis('off')
pyplot.show()
# Out:
# Loaded (1, 256, 256, 3)
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Loaded (256, 256, 3)

# %%
for example_input, example_target in test_dataset.take(1):
  generate_images(generator, example_input, example_target)
